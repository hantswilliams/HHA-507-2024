# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
# un: student_athletics
# pw: 
# hostname: @shtm-fallprev.mysql.database.azure.com
# databasename: sbu_athletics

# {dbtype}+{driver}://{username}:{password}@{hostname}/{dbname}

# engine = create_engine('mysql+pymysql://student_athletics:INSERTPASSWORDHERE@shtm-fallprev.mysql.database.azure.com/sbu_athletics')
# mysql = the type of the database that you are trying to connect o
# pymysql = the driver


engine = create_engine('mysql+pymysql://student_athletics:INSERTPASSWORDHERE!!@shtm-fallprev.mysql.database.azure.com/sbu_athletics')

# %%
df = pd.read_sql_table('analytics_sbusportcounts', engine)
df
# Out:
#       my_row_id  sbu_sport           timestamp table_name  count_value
# 0             1   Baseball 2024-06-14 18:25:18    kinexon        23965
# 1             2   Baseball 2024-06-14 18:25:18    hawkins       206479
# 2             3   Baseball 2024-06-14 18:25:18       vald         2088
# 3             4   Football 2024-06-14 18:25:18    kinexon       411465
# 4             5   Football 2024-06-14 18:25:18    hawkins       267990
# ...         ...        ...                 ...        ...          ...
# 3681       3682  Womes Lax 2024-09-11 05:12:35    hawkins       202708
# 3682       3683  Womes Lax 2024-09-11 05:12:35       vald         5148
# 3683       3684       None 2024-09-11 05:12:35    kinexon      1174072
# 3684       3685       None 2024-09-11 05:12:35    hawkins       444024
# 3685       3686       None 2024-09-11 05:12:35       vald        17280
#
# [3686 rows x 5 columns]

# %%
df_small = pd.read_sql_query(
    'select * from analytics_sbusportcounts limit 50',  # argument 1 - sql query
    engine                                              #query 2 is the connection string
    )
df_small
# Out:
#             sbu_sport           timestamp table_name  count_value
# 0            Baseball 2024-06-14 18:25:18    kinexon        23965
# 1            Baseball 2024-06-14 18:25:18    hawkins       206479
# 2            Baseball 2024-06-14 18:25:18       vald         2088
# 3            Football 2024-06-14 18:25:18    kinexon       411465
# 4            Football 2024-06-14 18:25:18    hawkins       267990
# 5            Football 2024-06-14 18:25:18       vald         9432
# 6     Mens Basketball 2024-06-14 18:25:18    kinexon       277352
# 7     Mens Basketball 2024-06-14 18:25:18    hawkins       119234
# 8     Mens Basketball 2024-06-14 18:25:18       vald         1572
# 9            Mens Lax 2024-06-14 18:25:18    hawkins       123883
# 10           Mens Lax 2024-06-14 18:25:18       vald         2352
# 11        Mens Soccer 2024-06-14 18:25:18    kinexon       224720
# 12        Mens Soccer 2024-06-14 18:25:18    hawkins        95146
# ...
